# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ewf_r_za
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-ewf_r_za
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.4 MB/s eta 0:00:00:00:01
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=43b57c16386c71fc3b3b6ea01e15cec44495ec08af5a86ffffbf2904a9f04386
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kkbc5sgf/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
# !pip install pytube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 806.7 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# !rm *
# Out:
# rm: cannot remove '*': No such file or directory

# %%
from pytube import YouTube

def video_saver(link, no):
    yt = YouTube(link)
    stream = yt.streams.filter(only_audio=True).first()
    stream.download("/kaggle/working/", filename=f"audio{no}.mp3")

    yt = YouTube(link).streams.first().download(filename=f"video{no}.mp4")
    
links = ["https://www.youtube.com/watch?v=XB4MIexjvY0&t=993s&pp=ygUKYWJkdWwgYmFyaQ%3D%3D", "https://www.youtube.com/watch?v=e7iXwE7mRZg&t=9s", "https://www.youtube.com/watch?v=s97xNQayJYU&pp=ygUPcHl0aG9uIHR1dG9yaWFs"]
for i, j  in enumerate(links):
    video_saver(j, i)

# %%
import os
vidpath = [i for i in os.listdir("/kaggle/working") if i.endswith(".mp4")]
audpath = [i for i in os.listdir("/kaggle/working") if i.endswith(".mp3")]

# %%
import whisper
model = whisper.load_model("base")
result = model.transcribe(audpath[0])["text"]
result
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 114MiB/s]
# /opt/conda/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
result = " So good morning, good afternoon and good evening guys, based on the time zones you all are coming from. So guys, before we start with the session, can you all please give me a quick confirmation if you all can see my screen and hear me loud and clear as well? Perfect. Thank you so much for the confirmation, everyone. So my name is Neeraj Kheria and I have been working in the SITNAS 3 for more than 13 years now. So the main agenda for today's session, we are going to discuss on the market basket analysis here, how the association rule mining works and how the upriarigh algorithm works. A small question that we can start with is, has it ever happened that you are out to buy something and you end up buying a lot more than you have planned? So this normally happens in the marketplaces, correct? So it's a phenomenon called as the impulsive buying and big retailers take advantage of machine learning and upriarigh algorithm to make sure that we tend to buy more and that's what we have defined as a market basket analysis. Now, first of all, let's discuss on that. So in today's world, the goal of any organization is to increase the revenue and can this be done by pitching just one product at a time to the customer? The answer is clearly unknown. Hence the organization began mining data related to frequently bought items. So market basket analysis is one of the key techniques used by large retailers to uncover associations between items. So they tend to find out the associations between different items and products that can be sold together, which gives assisting in right product placement. Typically, it figures out what products are being bought together and organizations can place products in a similar manner. Now let's understand this better with an example. Let's say we have people are people who buy bread usually buy butter too. So the marketing team at retail stores should target customers who buy bread and butter and provide them an offer to them so that they buy the third item that we have eggs or any kind of jam as well, correct? So if a customer buys bread and the butter and see a discount or an offer on eggs, they will be encouraged to spend more and buy the eggs. So this is what market basket analysis is all about. So this is a small example. Let's say if we take 10,000 items, say, or for supermarkets to our data scientists, just imagine the number of insights we can get out of it. And that is why association rules binding is also important to understand. So if you talk about association rule mining, then association rules can be thought of as an if then relationship. Suppose we have an item A. So item A is bought by the customer and then the chances of an item B being picked by the customer to under the same transaction ideas found out. So here we have simple if and then relationship. So there are two elements of these different rules. First of all, we have the end decision as an if. So this is basically an item or group of items that are typically found in the item sets or data sets. And then we have the consequence that is then. So here we have then. So then is basically use for them then comes along as an item with an end assistant or we can say a group of end decisions that we are seeing and any certain we have discussed. It is basically an item or group of items that we found in items sets of data sets. Now here comes a constraint. Suppose we made a rule about an item used. We still have around 9,999 items to consider for rulemaking as we discussed we have we are going to make use of 10,000 items. So this is where our pre pre our pre-ore algorithm comes into play. So before we understand the our pre-ore algorithm. Let's understand the main mathematics involved here. So there are three ways to measure the association. We have support, confidence and then we have lived. So as you can measure the association here, we have support, confidence and lift. So support gives the fraction of transactions which contain item a. Suppose if you are talking about support here, it is basically frequent the fraction of transactions which contains item a and b. So basically support tells us about the frequency. But against that we can say frequently bought items or the combination of items bought frequently by using the support. So with this we can filter out the items that have a low frequency. Then we have confidence. So it tells us how often the items a and b occur together given the number of times a occurs. So typically let's say when we work with the a priori algorithm, we define different terms accordingly. But how exactly we have to decide the value? That's the main question. And to be honest, there is not a specific way to define these terms. Suppose we have assigned the support value as two. Now what is what exactly this means is until and unless the item frequency is not the not to. So here we define support as to so until unless the items frequency is not to person, we will not consider that item for the a priori algorithm. So this makes sense as considering items that are bought less frequently is a waste of time. Because let's say if only two person of users are buying this item along with the item that they have bought, then obviously they're particularly used that we cannot even consider as for the a priori algorithm that we are going to work on here. Now suppose after filtering we still have around 5000 items left now creating association rules for them is a practically impossible task for anyone. And this is where the concept of lift comes into play. So basically it left indicates the strength of a rule over the random occurrence of a n b and it basically tell us the strength of any given rule here. So for finding that out we have simply divide support with the by the support by the support of a and then support of b. So focus on the denominator. It is the probability of the individual support values of a and b and not together. So lift explains the strength of a rule. So more the lift more is a strength. Let's say a. As opposed to we can say for a is to be so if a if then relation if so if you talk about if the relationship for a b then the lift value is four. So first let's say for this relation the lift value is four here that means if you buy a then a chance of buying b is four times. The lead value is four or we can say it's four times if the value here is two there is two times and so on as a part of the lift values of time. So let's get started with the priori algorithm and now let's see how exactly it works. All right so now let's discuss on the can stop this is what we discussed here the transitions at local market and here we have a we see for the in transition to we have a CD in transition three we have b CD in transition four we have a d e and then we have transition five we have a b CD. So let's say here if you find out the entire rules here then a if a then again they are going to purchase d if they buy a seed again they have the option of going for a if they buy a then they have the option of going for c and if they buy b and c together then they are going to buy by a as well. And then we can find out the supports again for if a is for those who are purchasing a the probability of buying d it is some in terms of support it is two by five in terms of confidence it is two by three in terms of lift it is 10 upon nine. Whereas for c again for a that means what is the possibility that those who have purchased c will be buying a so you can find the support as two by five confidence as two by four and lift us five by six same before c and same before b c and a so we can see how the probability is going to be distributed as we as we find out the possibility of one to be bought over the other. All right so now let's assume further on the a priori algorithm but so a priori algorithm uses frequent item data sets. Okay so item sets or data sets to generate the association rules. So it is based on the concept that a subset of a frequent item set must also be frequent item set must be a frequent item set and frequent item set is the item set whose support value is greater than a threshold value that we have support. So let's say we have now we're getting what exactly a frequent item set is what we discuss as now is an item set whose support value is greater than a threshold value. All right so now if we talk about a simple example now here we can let's say we have the following data of a store here so we have the transition ID here and then we had items. So here we have these one are transition IDs and here we have the items. So in transition one we have one three four two three five one two three five two five and one three five. So if you talk about the first iteration now let's assume the support value is two and then we can create the item sets of the size one and calculate their support values as you can see here. So as you can see here the item four has a support value of one support value of one here which is less than the minimum support value. So we are going to discard four in the upcoming iterations and we have and that's how we can have the final table defined here as the F and so here we are going to discard the value as four and then we are going to have the final value to be given to us. So the item sets support value is less than minimum support value that is two are going to be eliminated. Next we are going to create the item sets or size two and calculate their support values so all the combination or item sets in F and are used in the iteration. So here we have C2 and then we have the F and here. So basically here we are going to make use all the entire iteration here and item sets having support less than two are eliminated again and in this case we have one and two right. So let's now understand what exactly we mean by printing and how it makes a primary one of the best algorithms for finding the frequent item sets. So if you talk about pruning then we are going to divide the item sets in C3 into subsets and eliminate the subsets that are having a support value less than two from this given item sets here. So here we are going to work on the third iteration so we will discard one two and three. We are going to discard one two and three and one two and five as well. So they both as they both contain one or two and this means again and this is the main highlight of the a priori algorithm. So again here we are going to discard one and two and this is the main highlight of this entire algorithm here because again the one and two is a common thing available in these in these both data sets right. So this is the main highlight of our primary algorithm here and then if you talk about the fourth iteration so if you can say if any of the subsets of these items are that are not in F2 then we are going to remove that particular item sets. And then in terms of the fourth iteration let's suppose here we have the transition ID and here we have the item set and support available. So since the support of this item set is going to be less than two so we will stop here and the final item sets will have is the F31. And now still now we have not calculated the confidence value yet so this is something that we have to keep in mind. So with F3 we get the following item sets that means for one we have one 3 and 5 and subsets are one 3 one 5 3 5 one 3 and 5. We ask for item sets one again we have two 3 2 5 3 5 2 3 and 5 itself for the other item sets available. So for one we have one 3 5 these are subsets of one 3 one 5 3 5 one 3 and 5 whereas two 3 5 are subsets of two 3 3 5 2 5 2 3 and 5 and for every subset of I we have to verify the output rule. Now when we are going for applying rules here so we will create the rules and apply them on item set F3. So now let's assume a minimum confidence value is 60% so for every subset of whether that we have S of I so the output rule is going to be S is going to be recommended so S is going to simply recommend IS and then we have support it is I and then we can simply divide this by the support cell and to find the minimum confidence value is going to be 1 to 5. So here rule 1 here is 1 3 is again a subset that means 1 and 3 will result to 5 that means if a user is purchasing 1 and 3 both the items then we have a good possibility of the customer going for the fifth item as well. So here the confidence is going to be support 1 3 5 divided by a support 1 3 that is 2 by 3 that is 66.6 person that is 60 person. So here rule 1 is going to be selected and in rule 2 we have 1 5 1 3 5 minus 1 5 that means if the people if someone is purchasing 1 and 5 then they are going to have a good possibility of going for 3 as well where we are going to see the confidence and for finding the confidence we are simply going to again subtract support for 1 3 5 by support of 1 5 that is 2 by 2 and this is going to simply be transferred at 100 person and which is much greater than 60 person as well. And same way in rule 3 we have 3 5 1 3 5 3 1 5 that means here if someone is going for purchasing 3 and 5 then they are then they are going to have a high possibility of going for 1 as well. So here the confidence is support 1 3 5 divided by support 3 5 that we get as 66 by 66 person. And here the rule 3 is going to be selected here as you can see here. Now up right now if you if you talk about the application of rules here now when we are talking about this rule here we can see whenever the confidence is going to be more than more than 60 person defined here then this rule is going to be selected as again here in this rule 5 where what where those who are purchasing 3 they have a possibility of going for 1 5 both. So here the confidence is less than 60 person which is why this is going to be rejected. Same way for rule 6 as well. Same way here for rule 6 as well because here the confidence is going to be less than 60 person then that's why this is going to be rejected here. Because again we have we have assume a minimum confidence level for 60 person and wherever we are going to get the confidence less than 60 person we're simply going to reject that particular model here all right. So first of all that's how we had seen how we can create rules in app ripyory algorithms here. And the same steps can be implemented for these items said 2 3 5 and then we are going to try it and see which rules are accepted and which rules are going to be rejected and how we can implement the appryory algorithm in Python. All right so let's fetch some sample data sets here that we are going to work on. So to get started working on the actual analysis here we are going to make use of the PyCharm ID so we can use any of the ID or we can also make use of the Python or an IDLE to get started. So we are going to make use of PyCharm. In this file we'll be having the access to the invoice number we have the stock code we have description quantity invoice date unit price customer ID and then we have the country. So this is the data point that this is a file that we are going to work on. All right so in the meantime we are also going to install PyCharm as of main ID. So in case you want to work on Python then we can make use of PyCharm ID which is one of the most popular IDs for getting started and PyCharm is also offered as a free tool. Let me see here we get it is also offered as a community tool here. So we can use it as a community tool in order to get started. So once we have the access to it we can open this up. All right so here we can get started. First of all we are going to work on the pandas library. So here we are going to import pandas and MLX10 libraries imported to import and read the data sets. So here we are going to use import and then here we are going to find import pandas and from pandas as pd. So here we go to import pandas as pd and then we are going to use from MLX10. We are going for freequaint.frequent patterns. We are going to import our pure and then we are going to use the same from MLX10.frequent underscore patterns. We are again going to import association rules. They are going to import import association rules and then we are going to create a data frame where we are going to make use of pandas library as pd.read and here we are going to read excel file. If it is a CSE file let me define it as read CSV and here we can define the path. Suppose here the file is currently available in our users location and the users we have it in downloads and by the name of online underscore retail.excel.exe. So this is the breeder we have currently imported here and in case suppose some libraries are currently missing here so we can import these libraries as and when required here suppose if we if something is missing here we can simply import these in case they are not properly installed. So for installation of any library we can go to files on our settings. Here we have to go to project interpreter in case you want to add any specific library here then we can simply click on plus and then we can choose which library we want to add here. We can simply see the entire list of all the libraries currently installed here and now if we want to start with more then we can simply add more libraries and then we can start deploying it one by one. So for example suppose if we want to install any specific library here so here we can let's say here we want to install the a priori here so over again see here we can also import the MRA string so if this library is currently available we can simply click on install path and this is going to be installed and stored in a system as a library. Same way if you are looking for our priori here so here we can also use because again at the end we are going to use our priori from the MRA string that we have imported so here we are going to install the other package as well. So the full package for MRA string has been installed and now we are and now if you want to install the other packages then we can also install it. So in case we have missing some kind of library then we can simply install it or in case we are we have not used those libraries here then we can simply use them one by one so once we add them we can simply come out so as you can see now where is the library's hand been properly installed and we will be able see there is no error being shown here and this is the path of the file that where we have stored online's retails.exless file here so just to confirm we can confirm that we do have the file by the name of online retail.exless.ex available here in a downloads directory. So once we have specified the file here and then we are going to simply use dataframe.head so in case we want to see the first few entries of the current data set that we have imported so here we can simply define df.head and then from the green path the first you head is going to be return back as a response. Now once we add them we can simply start applying it. Now once we have the access to the data set here next step is going to be focus on data cleaning which will include removing spaces from some of the descriptions that we have and for that we are simply going to specify here we can now instead of using the the data page the data frame head here so now we are going to use the dataframe and then from here we are going to add a short description so here we can add a short description here so basically we are going to do work on data cleanup which includes removing spaces from some of the descriptions and then we are going to drop the rows that don't have invoice numbers and remove the correct transition as well for example suppose we have some rows where we don't have the where we have blank transitions it says right so we have some blank invoices and then we have invoices numbers and remove the correct transition where we don't have any kind of invoice number please here all right so we have we are to go in we have we are to work on removing those kind of anomalies so here from the data frame so here we can add parameter as description now on a description we are going to use the string function as string dot strip so string functions available under string we're going to make use of it and then same way from data frame we are going to work on dropping there we can find the values for x is equal to zero and then the subset where the well what kind of values we have to drop do you have to find that parameter where the invoice number is going to be in place is going to be true and then from data frame we can define the invoice frame the invoice number and then we can define it to be our data frame where invoice number again we are going to convert that to a string itself so here we can define data frame and then the invoice number type so here we have invoice number dot the as type and then we are going to all the as type here but again here we can keep it to as type so here we can define to be a string value so here we can find to be a string and then we can create a data frame where we can define data frame should be a value closer or get a value closer to data frame where we are going to define the invoice number so here we have invoice number and then we can define this as a string point based on the so here we have string dot contained and then we can define where the value see, where the value is see as a part of definition define here and then we are going to simply save it as a part of given data frame so after we are done cleaning up we need to consolidate the items into one transaction per row with each product so for sake of keeping the data small we are only going to look we are only going to be looking at the sales for the for any specific country so now once we are done we are going to create and consolidate the items into one transaction per row with each product and for the sake of keeping the data data says small we are going to look at the sales for specific country so for that let's say here we want to focus on one country data set here so here we can use basket and then in the basket part here we can define multiple data frames for example for support we can define data frame and here we are going to use the same data frame and then we are going to segregate it for the base on the country itself so here we can define country and then under country we can define which country we want to focus on the country should be suppose let's say France as a single country so here we can define France as a country that we want to use for consolidation and then we are going to group so here we can use group by the invoice number so here we are going to find the invoice number for it so here we have invoice number and then we can add a short description here so here we can add description and then after we are done defining the description here we can then define the quantity her so here we can define quantity and then after quantity we can define some Let's put this on the line just to what the confusion. So here we can define some and then we can define unstack.resets. We miss one other plan. This is here. So here we get to help you to define some and then we have define unstack and then we have define.reset.reset. And then the index value here with the final any with the final or case it is a simple. Well color with the simple fill and then we can define the value to be a simple zero. And then we can use set underscore index where we can define for the invoice number. So here we have invoice number define. And then we can define this for a basket. So basically here we are going to define the consolidation for the items into one transaction per row with each particular product. And the key the number of transition low we have we as progress attention only for a single concrete so as in France. So afterwards so after we are done with that part next we have to work on removing all the zero so basically there are a lot of zeros in the data but we also need to make sure that any positive values are converted to one and anything less than zero is also set to zero. So for that we are going to make use of this. So basically here we are now for converting that here we are going to make the go ahead and perform the encoding as well. So here we can define encoding units. So if x is less than or equals to zero then we are going to turn zero and if x is greater than or equals to one then it is going to turn one where we are going to define the basket sex and the basket apply map in code units. And then we are going to use simply use the drop postage and replace setter to be true here. So basically here we are going to simply work on first of all removing all the anomalies here. And then if there are lot of zeros in the data we also have to make sure that any positive values is converted to one and anything less than zero is also the zero that what we had done here. And then we are going to generate a frequent item set that have support value of at least seven person and this number is chosen so that we don't so that we can get close enough and we don't observe any kind of errors we don't get any any errors thrown. And here we can generate the frequent. Generate the rules with the corresponding support confidence and lift so for doing that we can make use of frequent item sets. So here we are going to define frequent item sets where we are going to find the Rp or E from basket said minimum support should be 0.7 and the call length that you are going to be used is should be true. And the rules here if I should be for association rules where we want to find the metric as lift and the minimum threshold to be said to one. And then we are going to filter the data frame using standard Panda score for a large lift and high confidence value as pointed. And then if we run this and we'll be able to see the output directly in the section all together. So here we can simply run rules and then if you run rules here we can define rules for lift it is going to be defined as a value greater than six and rules fair conference values going to be pointed altogether. So that's how we can make use of the our priority algorithm here. So as it's almost time now so let's do one thing let's say we wrap it up for today guys. Thank you"

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("kundank/usb-abstractive_summarization-flant5xl")
model = AutoModelForSeq2SeqLM.from_pretrained("kundank/usb-abstractive_summarization-flant5xl")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.58k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# ...

# %%
model.
# Out:
# <bound method Module.modules of T5ForConditionalGeneration(
#   (shared): Embedding(32100, 2048)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32100, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
# ...

# %%
import torch
from transformers import pipeline, BartForConditionalGeneration, BartTokenizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
chunk_size = 1024
chunks = [result[i:i+chunk_size] for i in range(0, len(result), chunk_size)]   
transformer = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn").to(device)
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")

summaries = []
for i, chunk in enumerate(chunks):
        inputs = tokenizer.encode(chunk, return_tensors='pt').to(device)
        summary_ids = transformer.generate(inputs, min_length=10, do_sample=True, temperature=0.7, top_k=50)[0]
        summary = tokenizer.decode(summary_ids, skip_special_tokens=True)
        summaries.append(summary)
summaries
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ['Neeraj Kheria is a senior analyst at SITNAS. He has been working in the company for more than 13 years. He will discuss on the market basket analysis and how the association rule mining works.',
#  'Market basket analysis is one of the key techniques used by large retailers to uncover associations between items. Typically, it figures out what products are being bought together and organizations can place products in a similar manner.',
# ...

# %%
print(len(summary))
print(len(result))

# %%
# !rm -rf /kaggle/working/output

# %%
import cv2
import numpy as np
import os
import time

cap = cv2.VideoCapture('/kaggle/working/video0.mp4')

fps = cap.get(cv2.CAP_PROP_FPS)

ret, prev_frame = cap.read()
black_threshold = 100 
threshold = 10  

output_dir = '/kaggle/working/output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

frame_index = 0
while ret:
    ret, curr_frame = cap.read()

    if not ret:
        continue
    
    if np.mean(curr_frame) < black_threshold:
        continue

    diff = cv2.absdiff(curr_frame, prev_frame)

    mean_diff = np.mean(diff)

    if mean_diff > threshold:
        timestamp = frame_index / fps
        timestamp_str = time.strftime("%H%M%S", time.gmtime(timestamp))
        cv2.imwrite(os.path.join(output_dir, f'frame_{timestamp_str}.png'), curr_frame)

    prev_frame = curr_frame
    frame_index += 1

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-iq89198b
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-iq89198b
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 79f914785a87b80565381f4489b129e633c4efb5
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 833.3 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 8.2 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
cfg = get_cfg()
im = cv2.imread("/kaggle/working/output/frame_000747.png")
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [05/24 18:06:44 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# !tar -zcvf out.tar.gz output
# Out:
# output/
# output/frame_001342.png.gz
# output/frame_001300.png.gz
# output/frame_001310.png.gz
# output/frame_001656.png.gz
# output/frame_000747.png.gz
# output/frame_000109.png.gz
# output/frame_001616.png.gz
# output/frame_000309.png.gz
# output/frame_000907.png.gz
# output/frame_001315.png.gz

# %%
import shutil

# Define the folder path and the output zip file path
folder_path = '/home/shusrith/Downloads'
output_zip = '/kaggle/working/output'

# Create a zip archive of the folder
shutil.make_archive(output_zip.replace('.zip', ''), 'zip', folder_path)
# Out:
# '/kaggle/working/output.zip'

# %%
print(outputs["instances"].pred_classes)
print(outputs["instances"].pred_boxes)
# Out:
# tensor([0], device='cuda:0')
# Boxes(tensor([[  0.0000,  34.9377, 273.3564, 357.3307]], device='cuda:0'))

# %%
# !pip install git+https://github.com/googlecolab/colabtools.git
# Out:
# ...
#   Cloning https://github.com/googlecolab/colabtools.git to /tmp/pip-req-build-4vbwruue
#   Running command git clone --filter=blob:none --quiet https://github.com/googlecolab/colabtools.git /tmp/pip-req-build-4vbwruue
#   Resolved https://github.com/googlecolab/colabtools.git to commit 0bb02aa78b7123874547092d3b1bd53ac6d5be5e
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.8/793.8 kB 8.8 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 62.0 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for google-colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=164656 sha256=857b3bdc305463f0c176d2c9fc651515ad7c84ab7eca83ac2f5923653e146b44
# ...

# %%
import cv2
from matplotlib import pyplot as plt
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog

# Assuming `im` is your input image and `cfg` is your configuration
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

# Convert BGR image (default in OpenCV) to RGB (default in Matplotlib)
image_rgb = out.get_image()[:, :, ::-1]

# Display the image inline
plt.imshow(image_rgb)
plt.axis('off')  # Hide the axis
plt.show()

# %%
masks = outputs["instances"].pred_masks.cpu().numpy()
scores = outputs["instances"].scores.cpu().numpy()
classes = outputs["instances"].pred_classes.cpu().numpy()

# Assuming you want to remove the segment with the highest score
# or you can use another criteria to choose the segment to remove
index_to_remove = np.argmax(scores)

# Create a mask to keep all segments except the one to remove
mask_to_keep = np.ones(masks.shape[0], dtype=bool)
mask_to_keep[index_to_remove] = False

# Combine the masks of the segments to keep
final_mask = np.any(masks[mask_to_keep], axis=0)

# Convert the mask to uint8
final_mask_uint8 = (final_mask * 255).astype(np.uint8)

# Invert the mask to remove the segment
mask_to_remove = cv2.bitwise_not(final_mask_uint8)

# Ensure the mask has three channels
mask_to_remove = cv2.merge([mask_to_remove, mask_to_remove, mask_to_remove])

# Remove the segment from the original image
im_removed_segment = cv2.bitwise_and(im, mask_to_remove)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(im_removed_segment, cv2.COLOR_BGR2RGB))
plt.title("Image with Segment Removed")
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import os
import time
from skimage import io
from skimage.metrics import structural_similarity as ssim

cap = cv2.VideoCaptureACCESS_FAST('/kaggle/working/video1.mp4')

fps = cap.get(cv2.CAP_PROP_FPS)

ret, prev_frame = cap.read()
black_threshold = 100 
threshold = 0.4

prev_frame = None
frame_index = 0
while ret:
    ret, curr_frame = cap.read()
    if not ret:
        continue
    
    curr_frame = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY) 

    if prev_frame is not None:
        if ssim(prev_frame, curr_frame) < threshold:
            plt.imshow(curr_frame, cmap="gray")
    if frame_index % 1000 == 0:
        print(frame_index)
    prev_frame = curr_frame
    frame_index += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 8
#       5 from skimage import io
#       6 from skimage.metrics import structural_similarity as ssim
# ----> 8 cap = cv2.VideoCaptureACCESS_FAST('/kaggle/working/video1.mp4')
#      10 fps = cap.get(cv2.CAP_PROP_FPS)
#      12 ret, prev_frame = cap.read()
#
# AttributeError: module 'cv2' has no attribute 'VideoCaptureACCESS_FAST'

# %%
len(os.listdir("/kaggle/working/output"))
# Out:
# 16

# %%
# !rm *.png

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

directory = '/kaggle/working/output'

files_in_directory = os.listdir(directory)

png_files = [file for file in files_in_directory if file.endswith('.png')]

for i, png_file in enumerate(png_files):
    plt.imshow(png_file)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       9 png_files = [file for file in files_in_directory if file.endswith('.png')]
#      11 for i, png_file in enumerate(png_files):
# ---> 12     plt.imshow(png_file)
#      13     plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# ...

# %%
from skimage import io
from skimage.metrics import structural_similarity as ssim
import cv2
image2 = None
for i in png_files:
    image1 = cv2.imread(f"/kaggle/working/output/{i}", cv2.IMREAD_GRAYSCALE)
    if image2 is not None:
        ssimvval = ssim(image1, image2)
        print('SSIM: ', ssimvval)
    image2 = image1
# Out:
# SSIM:  0.7012849933306967
# SSIM:  0.7511783878985283
# SSIM:  0.7674122948647448
# SSIM:  0.6831313999376329
# SSIM:  0.7252644663685728
# SSIM:  0.659943071712767
# SSIM:  0.7435408875563234
# SSIM:  0.6662846001753611
# SSIM:  0.773319498823051

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 582.1 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 4.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install super-gradients

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model("/kaggle/working/output/frame_000058.png")
# Out:
# image 1/1 /kaggle/working/output/frame_000058.png: 384x640 (no detections), 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.save(filename='output/result.jpg')  # save to disk
print(boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (360, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))

# %%
import matplotlib.pyplot as plt
from PIL import Image
plt.imshow(Image.open("/kaggle/working/output/result.jpg"))

# %%
a = boxes.xyxy
# a = list(map(int, a[0]))
a
# Out:
# tensor([], device='cuda:0', size=(0, 4))

# %%
img = Image.open("/kaggle/working/output/frame_001300.png")
width, height = img.size
cropped_image = img.crop((a[0], a[1], a[2], a[3]))
print(width, height)
# Remove the detected object from the original image

mask = Image.new("RGB", (width, height), (a[3], 0, 0))
mask.paste(img, (0, 0))
mask.paste((0, 0, 0), (a[0], 0, a[2], height))
plt.imshow(mask)
# Out:
# 640 360

# %%
# !pip install bert-extractive-summarizer

# %%
from summarizer import Summarizer
model = Summarizer()
s = model(result)
s
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
x = ' '.join(summaries)
x
# Out:
# "Neeraj Kheria is a senior analyst at SITNAS. He has been working in the company for more than 13 years. He will discuss on the market basket analysis and how the association rule mining works. Market basket analysis is one of the key techniques used by large retailers to uncover associations between items. Typically, it figures out what products are being bought together and organizations can place products in a similar manner. as well, correct? So if a customer buys bread and the butter and see a discount or an offer on eggs, they will be encouraged to spend more and buy the eggs. So this is what market basket analysis is all about. Let's say if we take 10,000 items, say, for supermarkets to our data scientists, just imagine the number of insights we can get out of it. Our pre pre our pre-ore algorithm comes into play. It is basically an item or group of items that we found in items sets of data sets. There are three ways to measure the association. We have support, confidence and 
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Tokenize paragraphs into sentences
sentences1 = sent_tokenize(x)
sentences2 = sent_tokenize(s)

# Combine sentences
all_sentences = sentences1 + sentences2

# Calculate TF-IDF vectors
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(all_sentences)

# Calculate cosine similarity between sentences
similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Merge sentences based on similarity
merged_sentences = []
merged_indices = set()

for i in range(len(all_sentences)):
    if i not in merged_indices:
        similar_indices = [j for j, sim in enumerate(similarity_matrix[i]) if sim > 0.5]
        merged_indices.update(similar_indices)
        merged_sentences.append(' '.join(all_sentences[j] for j in similar_indices))

# Combine merged sentences into a single paragraph
final_paragraph = ' '.join(merged_sentences)

print(final_paragraph)
# Out:
# Neeraj Kheria is a senior analyst at SITNAS. He has been working in the company for more than 13 years. He will discuss on the market basket analysis and how the association rule mining works. So the main agenda for today's session, we are going to discuss on the market basket analysis here, how the association rule mining works and how the upriarigh algorithm works. Market basket analysis is one of the key techniques used by large retailers to uncover associations between items. Typically, it figures out what products are being bought together and organizations can place products in a similar manner. as well, correct? So if a customer buys bread and the butter and see a discount or an offer on eggs, they will be encouraged to spend more and buy the eggs. So this is what market basket analysis is all about. Let's say if we take 10,000 items, say, for supermarkets to our data scientists, just imagine the number of insights we can get out of it. Our pre pre our pre-ore algorithm comes 
# ...

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large").to("cuda")

img_url = '/kaggle/working/output/frame_002545.png' 
raw_image = Image.open(img_url).convert('RGB')


inputs = processor(raw_image, return_tensors="pt").to("cuda")

out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1128: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# arafed image of a man standing in front of a whiteboard

# %%
import pytesseract
from PIL import Image

# Open the image file
img = Image.open('/kaggle/working/output/frame_002545.png')

# Use Tesseract to do OCR on the image
text = pytesseract.image_to_string(img)

print(text)

# %%
from dalle_pytorch import OpenAIDiscreteVAE, DALLE
from PIL import Image

# Load the DALL-E model
vae = OpenAIDiscreteVAE()
dalle = DALLE(vae = vae)

# Load the text prompt
text_prompt = "an armchair in the shape of an avocado"

# Generate an image from the text prompt
image = dalle.generate_images(text_prompt)

# Convert the image to a PIL Image and display it
image = Image.fromarray(image)
image.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from dalle_pytorch import OpenAIDiscreteVAE, DALLE
#       2 from PIL import Image
#       4 # Load the DALL-E model
#
# File /opt/conda/lib/python3.10/site-packages/dalle_pytorch/__init__.py:1
# ----> 1 from dalle_pytorch.dalle_pytorch import DALLE, CLIP, DiscreteVAE
#       2 from dalle_pytorch.vae import OpenAIDiscreteVAE, VQGanVAE
#       4 from pkg_resources import get_distribution
#
# File /opt/conda/lib/python3.10/site-packages/dalle_pytorch/dalle_pytorch.py:11
#       8 from einops import rearrange
#      10 from dalle_pytorch import distributed_utils
# ---> 11 from dalle_pytorch.vae import OpenAIDiscreteVAE, VQGanVAE
#      12 from dalle_pytorch.transformer import Transformer, DivideMax
#      14 # helpers
#
# File /opt/conda/lib/python3.10/site-packages/dalle_pytorch/vae.py:16
# ...

# %%
# !pip install dalle_pytorch

# %%
# !pip install pytorch_lightning --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 18.1 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: pytorch_lightning
#     Found existing installation: pytorch-lightning 2.1.3
#     Uninstalling pytorch-lightning-2.1.3:
#       Successfully uninstalled pytorch-lightning-2.1.3
# ...

# %%
# AIzaSyDGIUscGCysmfauYubzCzQ9XSmw-ub4BWM 
# 75f124136c79541ab

# %%
import requests
import json
from io import BytesIO
from PIL import Image

def search_images(search_term, count=5):
    cse_id = "75f124136c79541ab"
    search_url = "https://www.googleapis.com/customsearch/v1"

    params = {
        "q": search_term,
        "num": count,
        "start": 1,
        "imgSize": "medium",
        "searchType": "image",
        "key": api_key,
        "cx": cse_id
    }

    response = requests.get(search_url, params=params)
    response.raise_for_status()
    search_results = response.json()

    return [item['link'] for item in search_results['items']]


x = search_images("sun")
x
# Out:
# ['https://cdn.mos.cms.futurecdn.net/truJRnpVqJWCE3EaEjvaTk-320-80.jpg',
#  'https://spaceplace.nasa.gov/templates/featured/sun/all-about-the-sun300.jpg',
#  'https://cdn.mos.cms.futurecdn.net/7JwpfUpwtJMzQnjqPjHAqS-320-80.jpg',
#  'https://www.adl.org/sites/default/files/styles/glossary_term/public/images/2023-06/ezgif.com-resize%20%288%29.png.webp?itok=ajOnFUh5',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Sol_de_Mayo-Bandera_de_Argentina.svg/220px-Sol_de_Mayo-Bandera_de_Argentina.svg.png']

# %%
# !rm *

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

directory = '/kaggle/working'

files_in_directory = os.listdir(directory)

png_files = [file for file in files_in_directory if file.endswith('.jpg')]

for png_file in png_files:
    img = Image.open(os.path.join(directory, png_file))
    
    plt.imshow(img)
    plt.show()

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import matplotlib.pyplot as plt

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large").to("cuda")
l = []
for i in x:
    raw_image = Image.open(requests.get(i, stream=True).raw).convert('RGB')
    plt.imshow(raw_image)
    plt.show()

    inputs = processor(raw_image, return_tensors="pt").to("cuda")

    out = model.generate(**inputs)
    l.append(processor.decode(out[0], skip_special_tokens=True))
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1128: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 36.5 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
l
# Out:
# ["the sun is seen in this image taken by nasa's solar observatory",
#  'cartoon sun with a smile on its face in the night sky',
#  'the sun is shown in this image from nasa',
#  'a black and white circular design with arrows in the center',
#  'a yellow sun with a face on it']

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import spacy

nlp = spacy.load('en_core_web_md')

def sentence_to_vector(sentence):
    """
    Convert a sentence to a numerical vector representation
    using the average of word vectors.
    """
    tokens = nlp(sentence)
    word_vectors = np.array([token.vector for token in tokens if not token.is_stop and not token.is_punct])
    if len(word_vectors) > 0:
        return np.mean(word_vectors, axis=0)
    else:
        return None

def cosine_similarity_sentences(sentence1, sentence2):
    """
    Calculate the cosine similarity between two sentences
    based on their vector representations.
    """
    vector1 = sentence_to_vector(sentence1)
    vector2 = sentence_to_vector(sentence2)
    if vector1 is not None and vector2 is not None:
        return cosine_similarity([vector1], [vector2])[0][0]
    else:
        return None

# Example usage
sentence1 = "sun"
sentence2 = "the sun is seen in this image taken by nasa's solar observatory"

for i in l:
    similarity = cosine_similarity_sentences(sentence1, i)
    print("Cosine Similarity:", similarity)
# Out:
# Cosine Similarity: 0.6206533
# Cosine Similarity: 0.7910394
# Cosine Similarity: 0.68829405
# Cosine Similarity: 0.21575685
# Cosine Similarity: 0.8217431

# %%
import cv2
import numpy as np
from skimage.metrics import structural_similarity as compare_ssim

def calculate_ssim(frame1, frame2):
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
    return compare_ssim(gray_frame1, gray_frame2)

def extract_keyframes(video_path, threshold=0.9):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return
    
    success, prev_frame = cap.read()
    if not success:
        print("Error: Could not read first frame.")
        return
    
    keyframes = [prev_frame]
    count = 0
    while True:
        success, frame = cap.read()
        if not success:
            break
        
        ssim = calculate_ssim(prev_frame, frame)
        if ssim < threshold:
            keyframes.append(frame)
            prev_frame = frame
        count += 1
        if count % 1000 == 0:
            print(count)
    cap.release()
    return keyframes

def save_keyframes(keyframes, output_dir):
    for i, frame in enumerate(keyframes):
        cv2.imwrite(f"{output_dir}/keyframe_{i}.jpg", frame)

# Example usage
video_path = "/kaggle/working/video0.mp4"
output_dir = "/kaggle/working/output"
threshold = 0.8

keyframes = extract_keyframes(video_path, threshold)
save_keyframes(keyframes, output_dir)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000

# %%
x = "Neeraj Kheria is a senior analyst at SITNAS. He has been working in the company for more than 13 years. He will discuss on the market basket analysis and how the association rule mining works. So the main agenda for today's session, we are going to discuss on the market basket analysis here, how the association rule mining works and how the upriarigh algorithm works. Market basket analysis is one of the key techniques used by large retailers to uncover associations between items. Typically, it figures out what products are being bought together and organizations can place products in a similar manner. as well, correct? So if a customer buys bread and the butter and see a discount or an offer on eggs, they will be encouraged to spend more and buy the eggs. So this is what market basket analysis is all about. Let's say if we take 10,000 items, say, for supermarkets to our data scientists, just imagine the number of insights we can get out of it. Our pre pre our pre-ore algorithm comes into play. It is basically an item or group of items that we found in items sets of data sets. So this is basically an item or group of items that are typically found in the item sets or data sets. There are three ways to measure the association. We have support, confidence and then we have lived. Then we have confidence. So support gives the fraction of transactions which contain item a. Support tells us about the frequency. But against that we can say frequently bought items or the combination of items bought frequently. With this we can filter out the items that have a low frequency. Lift indicates the strength of a rule over the random occurrence of a n b. So more the lift more is a strength. Let's say a is to be so if a if then relation if so. ship for a b then the lift value is four. If you buy a then a chance of buying b is four times. So let's get started with the priori algorithm and now let's see how exactly it works. A priori algorithm uses frequent item data sets to generate the association rules. All right so now let's assume further on the a priori algorithm but so a priori algorithm uses frequent item data sets. Okay so item sets or data sets to generate the association rules. So it is based on the concept that a subset of a frequent item set must also be frequent. A frequent item set is an item set whose support value is greater than a threshold value. All right so now if we talk about a simple example now here we can let's say we have the following data of a store. We have the transition ID here and then we had items. And then in terms of the fourth iteration let's suppose here we have the transition ID and here we. So here we have these one are transition IDs and here we have the items. Printing is one of the best algorithms for finding the frequent item sets. We are going to create the item sets or size two and calculate their support values so all the combination or item sets in F are used in the iteration. ard one two and three and one two, five as well. So in transition one we have one three four two three five one two three five two five and one three five. We are going to discard one two and three and one two and five as well. So they both as they both contain one or two and this means again and this is the main highlight of the a priori algorithm. So they both as they both contain one or two and this means again and this is the main highlight of the a priori algorithm. have the item set and support available. So since the support of this item set is going to be less than two so we will stop here and the final item sets will have is the F31. For item set F3. F3 we get the following item sets that means for one we have one 3 and 5 and subsets are one 3 one 5 3 5. For every subset of I we have to verify the output rule. Now let's assume a minimum confidence value is 60% so for every. subset of whether that we have S of I so the. output rule is going to be S. In rule 1 we have 1 5 1 3 5 minus 1 5 that means if the people if someone is purchasing 1 and 5 then they are going to have a good possibility of going for 3 as well. So here rule 1 here is 1 3 is again a subset that means 1 and 3 will result to 5 that means if a user is purchasing 1 and 3 both the items then we have a good possibility of the customer going for the fifth item as well. In rule 3 we have 3 5 1. 3 5 3 1 5 and we get as 66 by 66.6 person that is 60 person. So here the confidence is support 1 3 5 divided by support 3 5 that we get as 66 by 66 person. So here the confidence is going to be support 1 3. Same way here for rule 6 as well because here the confidence is going to be less than 60 person then that's why this is going to be rejected here. 5 divided by a support 2 by 3. So here the confidence is support 1 3 5 divided by support 3 5 that we get as 66 by 66 person. The same steps can be implemented for these items said 2 3 5 an 5 an. can see here. Same way here for rule 6 as well. Same way here for rule 6 as well because here the confidence is going to be less than 60 person then that's why this is going to be rejected here. Because again we have we have assume a minimum confidence level for 60 person and wherever we are going to get the confidence less than 60 person we're simply going to reject that particular model. We are going to make use of the PyCharm ID to get started. We are also going to use the Python or an IDLE to get Started. In this file we'll be having the access to the invoice number we have the stock code we have description quantity invoice date unit price customer ID and then the country. So this is the data point that this is a file that we're going to work on. red as a community tool in order to get started. So once we have the access to it we can open this up. First of all we are going to work on the pandas library. o basically here we are going to simply work on first of all removing all the anomalies here. First of all we are going to work on the pandas library. We are going for freequaint.frequent patterns. We are going for freequaint.frequent patterns. For installation of any library we can go to files on our settings. Here we have to go to project interpreter in case you want to add any specific library here. Here we have to go to project interpreter in case you want to add any specific library here then we can simply click on plus and then we can choose which library we want to add here. We can simply see the entire list of all the libraries currently installed here and now if we want to start with more then we can simply add more libraries. If this library is currently available we can simply click on install path and this is going to be installed and stored in a system as a library. So for example suppose if we want to install any specific library here so here we can let's say here we want to install the a priori here so over again see here we can also import the MRA string so if this library is currently available we can simply click on install path and this is going to be installed and stored in a system as a library. So the full package for MRA string has been installed and now we are and now if you want to install the other packages then we can also install it. So the full package for MRA string has been installed and now we are and now if you want to install the other packages then we can also install it. Same way if you are looking for our priori here so here we can use because again at the end we are going to use our. Same way if you are looking for our priori here so here we can also use because again at the end we are going to use our priori from the MRA string that we have imported so here we are going to install the other package as well. priori from the MRA. string that we have imported. We are going to use the file of online retail.exless.ex available here in a downloads directory. Once we have specified the file here we can simply use dataframe.head so in case we want to see the first few entries of the current data set that we have imported. Now once we have the access to the data set here next step is going to be focus on data cleaning which will include removing spaces. ing spaces from some of the descriptions and then we are going to drop the rows that don't have invoice numbers and remove the correct transition as well. So we have we are to work on removing those kind of anomalies so here we can add parameter as description now on a description. We can create a data frame where we can define data frame should be a value closer or get a value close to invoice number where we are going to define the invoice number. We can then define where the value see, where thevalue is see as a part of definition define here and then we can simply save it as part of given data frame. items into one transaction per row with each product so for sake of keeping the data small we are only going to look at the sales for the for any specific country so now once we are done we are going to create and consolidate the items. re going to define the consolidation for the items into one transaction per row with each particular product. So here we get to help you to define some and then we have define unstack. So here we can define some and then we can define unstack.resets. And then we can use set underscore index where we can define for the invoice number. So here we have invoice number define. and thenwe can define this for a basket. And the key the number of transition low we have we have to as progress attention only for a single concrete so as in France. So afterwards so after we are done with that part next we have. to work on removing all the zero so basically there are a lot of zeros in the data. And then we are. going to generate a frequent item set that have support value of at least seven person and this number is chosen so that we don't. And then we are going to generate a frequent item set that have support value of at least seven person and this number is chosen so that we don't so that we can get close enough and we don't observe any kind of errors we don't get any any errors thrown. observe any kind of errors. And here we can generate the frequent. item sets with the corresponding support confidence and lift so for doing that we can make use of frequent item sets. hreshold to be said to one. And then we are going to filter the data frame using standard Panda score for a large lift and high confidence value as pointed. Rules fair conference values going to be pointed altogether. So here we can simply run rules and then if you run rules here we can define rules for lift it is going to be defined as a value greater than six and rules fair conference values going to be pointed altogether. So good morning, good afternoon and good evening guys, based on the time zones you all are coming from. So it's a phenomenon called as the impulsive buying and big retailers take advantage of machine learning and upriarigh algorithm to make sure that we tend to buy more and that's what we have defined as a market basket analysis. Now, first of all, let's discuss on that. Hence the organization began mining data related to frequently bought items. And to be honest, there is not a specific way to define these terms. Now what is what exactly this means is until and unless the item frequency is not the not to. And this is where the concept of lift comes into play. Whereas for c again for a that means what is the possibility that those who have purchased c will be buying a so you can find the support as two by five confidence as two by four and lift us five by six same before c and same before b c and a so we can see how the probability is going to be distributed as we as we find out the possibility of one to be bought over the other. So as you can see here the item four has a support value of one support value of one here which is less than the minimum support value. All right so let's fetch some sample data sets here that we are going to work on. They are going to import import association rules and then we are going to create a data frame where we are going to make use of pandas library as pd.read and here we are going to read excel file. And then the index value here with the final any with the final or case it is a simple."

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

# Load pre-trained T5 model and tokenizer
model_name = "t5-base"
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)


# Generate multiple-choice question
input_text = "generate question: " + x
input_ids = tokenizer.encode(input_text, return_tensors="pt")
outputs = model.generate(input_ids, max_length=50, num_return_sequences=1)
generated_question = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Generated MCQ:", generated_question)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Token indices sequence length is longer than the specified maximum sequence length for this model (2827 > 512). Running this sequence through the model will result in indexing errors
# Generated MCQ: a priori algorithm uses frequent item data sets to generate association rules. a priori algorithm uses frequent item data sets to generate association rules. a priori algorithm uses confidence and lift to determine the likelihood of a purchase

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

class MultiHeadSelfAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        if embed_dim % num_heads != 0:
            raise ValueError(
                f"embedding dimension = {embed_dim} should be divisible by number of heads = {num_heads}"
            )
        self.projection_dim = embed_dim // num_heads
        self.query_dense = layers.Dense(embed_dim)
        self.key_dense = layers.Dense(embed_dim)
        self.value_dense = layers.Dense(embed_dim)
        self.combine_heads = layers.Dense(embed_dim)

    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights

    def separate_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs, training=False):
        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        query = self.separate_heads(query, batch_size)
        key = self.separate_heads(key, batch_size)
        value = self.separate_heads(value, batch_size)

        attention, weights = self.attention(query, key, value)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        output = self.combine_heads(concat_attention)
        return output, weights

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training=False):
        attn_output, _ = self.att(inputs, training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output), _


class TokenAndPositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = tf.keras.layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, embed_dim, num_heads, ff_dim, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.embed_dim = embed_dim
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, embed_dim)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.embed_dim)

        self.enc_layers = [TransformerBlock(embed_dim, num_heads, ff_dim, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training):
        seq_len = tf.shape(x)[1]

        # adding embedding and position encoding
        x = self.embedding(x)  # (batch_size, input_seq_len, embed_dim)
        x *= tf.math.sqrt(tf.cast(self.embed_dim, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training)

        return x  # (batch_size, input_seq_len, embed_dim)

class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, embed_dim, num_heads, ff_dim, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.embed_dim = embed_dim
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, embed_dim)
        self.pos_encoding = positional_encoding(maximum_position_encoding, embed_dim)

        self.dec_layers = [TransformerBlock(embed_dim, num_heads, ff_dim, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)  # (batch_size, target_seq_len, embed_dim)
        x *= tf.math.sqrt(tf.cast(self.embed_dim, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        # x.shape == (batch_size, target_seq_len, embed_dim)
        return x, attention_weights

# %%
import numpy as np
def positional_encoding(position, embed_dim):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(embed_dim)[np.newaxis, :],
        embed_dim
    )

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, embed_dim):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(embed_dim))
    return pos * angle_rates

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load the dataset
summaries = pd.read_csv('/kaggle/input/narrativeqa/summaries.csv')
qas = pd.read_csv('/kaggle/input/narrativeqa/qaps.csv')

# Merge the summaries and questions into a single DataFrame
data = pd.merge(summaries, qas, on='document_id')

# Tokenize the summaries and questions
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data['summary'])
summary_sequences = tokenizer.texts_to_sequences(data['summary'])
question_sequences = tokenizer.texts_to_sequences(data['question'])

# Pad the sequences
summary_sequences = pad_sequences(summary_sequences, padding='post')
question_sequences = pad_sequences(question_sequences, padding='post')

# Define the model
embed_dim = 32  # Embedding size for each token
num_heads = 2  # Number of attention heads
ff_dim = 32  # Hidden layer size in feed forward network inside transformer
num_layers = 6

input_vocab_size = 8500  # You should set this to the size of your vocabulary
maximum_position_encoding = 10000  # This should be larger than the maximum sentence length in your dataset

encoder = Encoder(num_layers, embed_dim, num_heads, ff_dim, input_vocab_size, maximum_position_encoding)
decoder = Decoder(num_layers, embed_dim, num_heads, ff_dim, input_vocab_size, maximum_position_encoding)

inputs = tf.keras.Input(shape=(None,), dtype=tf.int32)
enc_outputs = encoder(inputs, training=True)
outputs, _ = decoder(inputs, enc_outputs, training=True)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy")

# Train the model
model.fit(summary_sequences, question_sequences, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 35
#      32 decoder = Decoder(num_layers, embed_dim, num_heads, ff_dim, input_vocab_size, maximum_position_encoding)
#      34 inputs = tf.keras.Input(shape=(None,), dtype=tf.int32)
# ---> 35 enc_outputs = encoder(inputs, training=True)
#      36 outputs, _ = decoder(inputs, enc_outputs, training=True)
#      38 model = tf.keras.Model(inputs=inputs, outputs=outputs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
x = "Neeraj Kheria is a senior analyst at SITNAS. He has been working in the company for more than 13 years. He will discuss on the market basket analysis and how the association rule mining works. So the main agenda for today's session, we are going to discuss on the market basket analysis here, how the association rule mining works and how the upriarigh algorithm works. Market basket analysis is one of the key techniques used by large retailers to uncover associations between items. Typically, it figures out what products are being bought together and organizations can place products in a similar manner. as well, correct? So if a customer buys bread and the butter and see a discount or an offer on eggs, they will be encouraged to spend more and buy the eggs. So this is what market basket analysis is all about. Let's say if we take 10,000 items, say, for supermarkets to our data scientists, just imagine the number of insights we can get out of it. Our pre pre our pre-ore algorithm comes into play. It is basically an item or group of items that we found in items sets of data sets. So this is basically an item or group of items that are typically found in the item sets or data sets. There are three ways to measure the association. We have support, confidence and then we have lived. Then we have confidence. So support gives the fraction of transactions which contain item a. Support tells us about the frequency. But against that we can say frequently bought items or the combination of items bought frequently. With this we can filter out the items that have a low frequency. Lift indicates the strength of a rule over the random occurrence of a n b. So more the lift more is a strength. Let's say a is to be so if a if then relation if so. ship for a b then the lift value is four. If you buy a then a chance of buying b is four times. So let's get started with the priori algorithm and now let's see how exactly it works. A priori algorithm uses frequent item data sets to generate the association rules. All right so now let's assume further on the a priori algorithm but so a priori algorithm uses frequent item data sets. Okay so item sets or data sets to generate the association rules. So it is based on the concept that a subset of a frequent item set must also be frequent. A frequent item set is an item set whose support value is greater than a threshold value. All right so now if we talk about a simple example now here we can let's say we have the following data of a store. We have the transition ID here and then we had items. And then in terms of the fourth iteration let's suppose here we have the transition ID and here we. So here we have these one are transition IDs and here we have the items. Printing is one of the best algorithms for finding the frequent item sets. We are going to create the item sets or size two and calculate their support values so all the combination or item sets in F are used in the iteration. ard one two and three and one two, five as well. So in transition one we have one three four two three five one two three five two five and one three five. We are going to discard one two and three and one two and five as well. So they both as they both contain one or two and this means again and this is the main highlight of the a priori algorithm. So they both as they both contain one or two and this means again and this is the main highlight of the a priori algorithm. have the item set and support available. So since the support of this item set is going to be less than two so we will stop here and the final item sets will have is the F31. For item set F3. F3 we get the following item sets that means for one we have one 3 and 5 and subsets are one 3 one 5 3 5. For every subset of I we have to verify the output rule. Now let's assume a minimum confidence value is 60% so for every. subset of whether that we have S of I so the. output rule is going to be S. In rule 1 we have 1 5 1 3 5 minus 1 5 that means if the people if someone is purchasing 1 and 5 then they are going to have a good possibility of going for 3 as well. So here rule 1 here is 1 3 is again a subset that means 1 and 3 will result to 5 that means if a user is purchasing 1 and 3 both the items then we have a good possibility of the customer going for the fifth item as well. In rule 3 we have 3 5 1. 3 5 3 1 5 and we get as 66 by 66.6 person that is 60 person. So here the confidence is support 1 3 5 divided by support 3 5 that we get as 66 by 66 person. So here the confidence is going to be support 1 3. Same way here for rule 6 as well because here the confidence is going to be less than 60 person then that's why this is going to be rejected here. 5 divided by a support 2 by 3. So here the confidence is support 1 3 5 divided by support 3 5 that we get as 66 by 66 person. The same steps can be implemented for these items said 2 3 5 an 5 an. can see here. Same way here for rule 6 as well. Same way here for rule 6 as well because here the confidence is going to be less than 60 person then that's why this is going to be rejected here. Because again we have we have assume a minimum confidence level for 60 person and wherever we are going to get the confidence less than 60 person we're simply going to reject that particular model. We are going to make use of the PyCharm ID to get started. We are also going to use the Python or an IDLE to get Started. In this file we'll be having the access to the invoice number we have the stock code we have description quantity invoice date unit price customer ID and then the country. So this is the data point that this is a file that we're going to work on. red as a community tool in order to get started. So once we have the access to it we can open this up. First of all we are going to work on the pandas library. o basically here we are going to simply work on first of all removing all the anomalies here. First of all we are going to work on the pandas library. We are going for freequaint.frequent patterns. We are going for freequaint.frequent patterns. For installation of any library we can go to files on our settings. Here we have to go to project interpreter in case you want to add any specific library here. Here we have to go to project interpreter in case you want to add any specific library here then we can simply click on plus and then we can choose which library we want to add here. We can simply see the entire list of all the libraries currently installed here and now if we want to start with more then we can simply add more libraries. If this library is currently available we can simply click on install path and this is going to be installed and stored in a system as a library. So for example suppose if we want to install any specific library here so here we can let's say here we want to install the a priori here so over again see here we can also import the MRA string so if this library is currently available we can simply click on install path and this is going to be installed and stored in a system as a library. So the full package for MRA string has been installed and now we are and now if you want to install the other packages then we can also install it. So the full package for MRA string has been installed and now we are and now if you want to install the other packages then we can also install it. Same way if you are looking for our priori here so here we can use because again at the end we are going to use our. Same way if you are looking for our priori here so here we can also use because again at the end we are going to use our priori from the MRA string that we have imported so here we are going to install the other package as well. priori from the MRA. string that we have imported. We are going to use the file of online retail.exless.ex available here in a downloads directory. Once we have specified the file here we can simply use dataframe.head so in case we want to see the first few entries of the current data set that we have imported. Now once we have the access to the data set here next step is going to be focus on data cleaning which will include removing spaces. ing spaces from some of the descriptions and then we are going to drop the rows that don't have invoice numbers and remove the correct transition as well. So we have we are to work on removing those kind of anomalies so here we can add parameter as description now on a description. We can create a data frame where we can define data frame should be a value closer or get a value close to invoice number where we are going to define the invoice number. We can then define where the value see, where thevalue is see as a part of definition define here and then we can simply save it as part of given data frame. items into one transaction per row with each product so for sake of keeping the data small we are only going to look at the sales for the for any specific country so now once we are done we are going to create and consolidate the items. re going to define the consolidation for the items into one transaction per row with each particular product. So here we get to help you to define some and then we have define unstack. So here we can define some and then we can define unstack.resets. And then we can use set underscore index where we can define for the invoice number. So here we have invoice number define. and thenwe can define this for a basket. And the key the number of transition low we have we have to as progress attention only for a single concrete so as in France. So afterwards so after we are done with that part next we have. to work on removing all the zero so basically there are a lot of zeros in the data. And then we are. going to generate a frequent item set that have support value of at least seven person and this number is chosen so that we don't. And then we are going to generate a frequent item set that have support value of at least seven person and this number is chosen so that we don't so that we can get close enough and we don't observe any kind of errors we don't get any any errors thrown. observe any kind of errors. And here we can generate the frequent. item sets with the corresponding support confidence and lift so for doing that we can make use of frequent item sets. hreshold to be said to one. And then we are going to filter the data frame using standard Panda score for a large lift and high confidence value as pointed. Rules fair conference values going to be pointed altogether. So here we can simply run rules and then if you run rules here we can define rules for lift it is going to be defined as a value greater than six and rules fair conference values going to be pointed altogether. So good morning, good afternoon and good evening guys, based on the time zones you all are coming from. So it's a phenomenon called as the impulsive buying and big retailers take advantage of machine learning and upriarigh algorithm to make sure that we tend to buy more and that's what we have defined as a market basket analysis. Now, first of all, let's discuss on that. Hence the organization began mining data related to frequently bought items. And to be honest, there is not a specific way to define these terms. Now what is what exactly this means is until and unless the item frequency is not the not to. And this is where the concept of lift comes into play. Whereas for c again for a that means what is the possibility that those who have purchased c will be buying a so you can find the support as two by five confidence as two by four and lift us five by six same before c and same before b c and a so we can see how the probability is going to be distributed as we as we find out the possibility of one to be bought over the other. So as you can see here the item four has a support value of one support value of one here which is less than the minimum support value. All right so let's fetch some sample data sets here that we are going to work on. They are going to import import association rules and then we are going to create a data frame where we are going to make use of pandas library as pd.read and here we are going to read excel file. And then the index value here with the final any with the final or case it is a simple."

# %%
from transformers import T5ForConditionalGeneration, T5TokenizerFast

hfmodel = T5ForConditionalGeneration.from_pretrained("ThomasSimonini/t5-end2end-question-generation")
tokenizer = T5TokenizerFast.from_pretrained("t5-base")# text= "The abolition of feudal privileges by the National Constituent Assembly on 4 August 1789 and the Declaration \\nof the Rights of Man and of the Citizen (La Déclaration des Droits de l'Homme et du Citoyen), drafted by Lafayette \\nwith the help of Thomas Jefferson and adopted on 26 August, paved the way to a Constitutional Monarchy \\n(4 September 1791 – 21 September 1792). Despite these dramatic changes, life at the court continued, while the situation \\nin Paris was becoming critical because of bread shortages in September. On 5 October 1789, a crowd from Paris descended upon Versailles \\nand forced the royal family to move to the Tuileries Palace in Paris, where they lived under a form of house arrest under \\nthe watch of Lafayette's Garde Nationale, while the Comte de Provence and his wife were allowed to reside in the \\nPetit Luxembourg, where they remained until they went into exile on 20 June 1791."

def run_model(input_string, **generator_args):
      generator_args = {
      "max_length": 1024,
      "num_beams": 40,
      "length_penalty": 1.5,
      "no_repeat_ngram_size": 30,
      "early_stopping": False,
      }
      input_string = "generate questions: " + input_string + " </s>"
      input_ids = tokenizer.encode(text=input_string, return_tensors="pt")
      res = hfmodel.generate(input_ids, **generator_args)
      output = tokenizer.batch_decode(res, skip_special_tokens=True)
      output = [item.split("<sep>") for item in output]
      return output

s = run_model(x)
s
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2828 > 512). Running this sequence through the model will result in indexing errors
# [['Who is a senior analyst at SITNAS? What is one of the key techniques used by large retailers to uncover associations between items? What is one of the best algorithms for finding the frequent item sets? What is a frequent item set whose support value is greater than a threshold value?']]
